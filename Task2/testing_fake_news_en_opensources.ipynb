# %%
import pandas as pd
import General_generate_topics_of_fact

df = pd.read_csv("hf://datasets/andyP/fake_news_en_opensources/opensources_fake_news_cleaned.csv", nrows=100)
articles = list(df["content"])

results = General_generate_topics_of_fact.generate_fake_news(articles, 2, 3, 2, print_comments=True)
#Desplay final_results in table format

final_results = results.dropna()
display(final_results)
final_results.to_csv('fake_news_en_opensource_1.csv', index=False)
# Out:
# Here are the topics extracted from the article:
#
# [
#   {
#     "Name of fact": "Mythic quality",
#     "Description of fact": "The quality that makes a story timeless and memorable.",
#     "Common examples": "Harry Potter, Lord of the Rings"
#   },
#   {
#     "Name of fact": "Storytelling framework",
#     "Description of fact": "A way of telling stories, such as standalone films or serialized narratives.",
#     "Common examples": "Marvel franchise, Disney's Star Wars plan"
#   },
#   {
#     "Name of fact": "Star Wars universe",
#     "Description of fact": "The vast and complex world created by Lucasfilm, including films, TV shows, and other media.",
#     "Common examples": "Expanded Universe, Original trilogy"
#   },
#   {
#     "Name of fact": "Character development",
#     "Description of fact": "The way characters are written and portrayed in a story, such as being more 'real' or relatable.",
#     "Common examples": "J.J. Abrams' approach to character creation"
#   },
# ...
