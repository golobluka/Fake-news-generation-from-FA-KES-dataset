# %%
import io
from contextlib import redirect_stdout

def my_function():
    print("This is the first line of output.")
    print("This is another line of output.")
    return "Function completed"

def save_output_to_file(func, file_path, *args, **kwargs):
    """
    Execute a function, capture its printed output, 
    and save the output to a specified text file.
    
    Parameters:
    - func: The function to be executed.
    - file_path: The path to the text file where output will be saved.
    - *args: Positional arguments to pass to the function.
    - **kwargs: Keyword arguments to pass to the function.
    
    Returns:
    - The return value of the function.
    """
    # Create a StringIO object to capture the output
    output_buffer = io.StringIO()
    
    # Redirect stdout to the StringIO buffer and execute the function
    with redirect_stdout(output_buffer):
        return_value = func(*args, **kwargs)
    
    # Retrieve the captured output from the buffer
    console_output = output_buffer.getvalue()
    
    # Save the output to a text file
    with open(file_path, 'w') as file:
        file.write(console_output)
    
    return return_value

# %%
import fake_detector 
import pandas as pd
import os


load_folder = "changed_articles"
name_of_loaded_file = "fake_articles_one_by_one_generation.csv"
path_string_load = os.path.join(load_folder, name_of_loaded_file)
model_name = "gemma2:9b"

data = pd.read_csv(path_string_load)
data = data.dropna()

print(data.values.tolist())
print(data.shape)

save_folder = "saved_prints"
name_of_saved_file = "results_53_data_clean_mixtral:8x7b_prits.txt"
path_string_save_comments = os.path.join(save_folder, name_of_saved_file)

results = fake_detector.fake_detect_comparison_true_to_true_and_false_to_true(data.values.tolist(), model_name, print_comments = True)

save_folder = "saved_results"
name_of_saved_file = "results_53_data_clean_gemma2:9b.csv"
path_save_string = os.path.join(save_folder, name_of_saved_file)

results.to_csv(path_save_string, index = False)
# Out:
# d:\Users\mihac\AppData\Roaming\Python\Python38\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# ...
